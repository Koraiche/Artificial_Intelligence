# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
dataset = pd.read_csv(r"C:\Users\PC\Jupyter Notebook\Deep Learning\S2M-Project\datasets\transaction_dataset.csv", index_col=0)

# %%
print(dataset.shape)
# Out:
# (6435, 59)

# %%
dataset.head
# Out:
# <bound method NDFrame.head of           TST_ACQR_BIN TST_ACQR_MRCH_ID TST_ACS_CHLL_MNDT_INDC  \
# TST_CODE
# 44,614           999.0    9876543210001                    NaN
# 45,615           999.0    9876543210001                    NaN
# 64,053        400551.0    9876543210001                    NaN
# 64,054        400551.0    9876543210001                    NaN
# 64,131        400551.0    9876543210001                      Y
# ...                ...              ...                    ...
# 47,185           999.0    9876543210001                    NaN
# 47,486             NaN              NaN                      Y
# 47,107           999.0    9876543210001                      Y
# 51,536             NaN              NaN                      Y
# 54,309           999.0    9876543210001                      Y
#
#           TST_ACS_CNTR_ACS_TO_SDK                        TST_ACS_TRX_ID  \
# TST_CODE
# 44,614                          0  67ffde63-44a2-4291-94ae-f157a8c18bbe
# ...

# %%
dataset.iloc[0]
# Out:
# TST_ACQR_BIN                                                           999.0
# TST_ACQR_MRCH_ID                                               9876543210001
# TST_ACS_CHLL_MNDT_INDC                                                   NaN
# TST_ACS_CNTR_ACS_TO_SDK                                                    0
# TST_ACS_TRX_ID                          67ffde63-44a2-4291-94ae-f157a8c18bbe
# TST_AREQ_DTTM                                        2020-10-09 18:22:41.309
# TST_AREQ_MSSG              {"threeRIInd":"04","threeDSRequestorID":"2767"...
# TST_ARES_DTTM                                        2020-10-09 18:22:43.195
# TST_ARES_MSSG              {"threeDSServerTransID":"0934fc38-0a54-11eb-bb...
# TST_ATHN_VALU                                   AABBCCDDEEFFAABBCCDDEEFFAAA=
# TST_ATHN_MTHD                                                            NaN
# TST_ATHN_TYPE                                                            NaN
# ...

# %%
dataframe = dataset[['TST_PRCH_AMNT','TST_TRX_DATE','TST_TRX_STTS','TST_PRCH_CRRC','TST_PRCH_DATE_TIME','TST_MRCH_CTGR_CODE','TST_MRCH_CNTR_CODE']]

# %%
dataframe.dropna()
# Out:
#          TST_PRCH_AMNT             TST_TRX_DATE TST_TRX_STTS  TST_PRCH_CRRC  \
# TST_CODE
# 64,131           4,246  2021-08-28 22:41:24.784            C          840.0
# 64,049             592  2021-08-10 10:48:05.325            N          840.0
# 64,050             592  2021-08-10 10:48:47.082            Y          840.0
# 64,051             592  2021-08-10 10:49:03.643            N          840.0
# 60,645             339  2020-12-20 23:33:00.654            C          840.0
# ...                ...                      ...          ...            ...
# 64,261           5,055  2021-09-21 23:53:20.721            N          504.0
# 64,262           5,055  2021-09-21 23:55:41.227            N          504.0
# 26,682           3,400  2020-08-05 23:22:25.398            Y          840.0
# 47,107             100  2020-10-10 10:47:51.831            Y          840.0
# 54,309           3,438  2020-10-13 19:03:51.505            C          840.0
#
# ...

# %%
dataframe.isna().sum()
# Out:
# TST_PRCH_AMNT            0
# TST_TRX_DATE             2
# TST_TRX_STTS          1791
# TST_PRCH_CRRC         3031
# TST_PRCH_DATE_TIME    3031
# TST_MRCH_CTGR_CODE    3136
# TST_MRCH_CNTR_CODE    3136
# dtype: int64
